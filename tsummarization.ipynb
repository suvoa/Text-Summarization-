# %% [markdown]
# 1. facebook/bart-large-cnn-------------------govreport-summarization

# %%
# !pip install transformers datasets rouge-score

from transformers import BartTokenizer, BartForConditionalGeneration
from datasets import load_dataset
from rouge_score import rouge_scorer

tokenizer = BartTokenizer.from_pretrained("mistralai/Mistral-Small-24B-Instruct-2501")
model = BartForConditionalGeneration.from_pretrained("mistralai/Mistral-Small-24B-Instruct-2501")

dataset = load_dataset("ccdv/govreport-summarization")

num_rows = len(dataset["train"])
features = dataset["train"].column_names

print(f"🔹 Total Rows: {num_rows}")
print(f"🔹 Features: {features}")

sample_text = dataset["train"][0]["report"]
reference_summary = dataset["train"][0]["summary"]

inputs = tokenizer(sample_text, return_tensors="pt", max_length=1024, truncation=True)

summary_ids = model.generate(**inputs, max_length=200, min_length=50, num_beams=4)
generated_summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)

scorer = rouge_scorer.RougeScorer(["rouge1", "rouge2", "rougeL"], use_stemmer=True)
rouge_scores = scorer.score(reference_summary, generated_summary)

print("\n🔹 **Original Text:**\n", sample_text[:1000])  # Print first 1000 chars
print("\n🔹 **Generated Summary:**\n", generated_summary)
print("\n🔹 **Reference Summary:**\n", reference_summary)

print("\n🔹 **ROUGE Scores:**")
print(f"ROUGE-1 (Unigrams)  : {rouge_scores['rouge1'].fmeasure:.4f}")
print(f"ROUGE-2 (Bigrams)   : {rouge_scores['rouge2'].fmeasure:.4f}")
print(f"ROUGE-L (Longest Match): {rouge_scores['rougeL'].fmeasure:.4f}")
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.4/485.4 kB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 8.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 6.9 MB/s eta 0:00:00
# ...
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24935 sha256=79e2776c5ad4f0e1fbe4e1a5a817a7bbb5de2fb53cfc2ea90353557287af1ac6
#   Stored in directory: /root/.cache/pip/wheels/1e/19/43/8a442dc83660ca25e163e1bd1f89919284ab0d0c1475475148
# Successfully built rouge-score
# ...
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:104: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# ...

# %% [markdown]
# 2.pegasus

# %%
# !pip install transformers datasets rouge-score

from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
from datasets import load_dataset
from rouge_score import rouge_scorer

tokenizer = AutoTokenizer.from_pretrained("google/pegasus-cnn_dailymail")
model = AutoModelForSeq2SeqLM.from_pretrained("google/pegasus-cnn_dailymail")

dataset = load_dataset("ccdv/govreport-summarization")

num_rows = len(dataset["train"])
features = dataset["train"].column_names

print(f"🔹 Total Rows: {num_rows}")
print(f"🔹 Features: {features}")

sample_text = dataset["train"][0]["report"]
reference_summary = dataset["train"][0]["summary"]

inputs = tokenizer(sample_text[:1024], return_tensors="pt", max_length=1024, truncation=True)

summary_ids = model.generate(inputs["input_ids"], max_length=150, min_length=40, num_beams=4)
generated_summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)

scorer = rouge_scorer.RougeScorer(["rouge1", "rouge2", "rougeL"], use_stemmer=True)
rouge_scores = scorer.score(reference_summary, generated_summary)

print("\n🔹 **Original Text (First 300 chars):**\n", sample_text[:300], "...")
print("\n🔹 **Generated Summary:**\n", generated_summary)
print("\n🔹 **Reference Summary:**\n", reference_summary)

print("\n🔹 **ROUGE Scores:**")
print(f"ROUGE-1 (Unigrams)  : {rouge_scores['rouge1'].fmeasure:.4f}")
print(f"ROUGE-2 (Bigrams)   : {rouge_scores['rouge2'].fmeasure:.4f}")
print(f"ROUGE-L (Longest Match): {rouge_scores['rougeL'].fmeasure:.4f}")
# Out:
# ...
# tokenizer_config.json:   0%|          | 0.00/88.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.12k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/1.91M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.28G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.28G [00:00<?, ?B/s]
# Some weights of PegasusForConditionalGeneration were not initialized from the model checkpoint at google/pegasus-cnn_dailymail and are newly initialized: ['model.decoder.embed_positions.weight', 'model.encoder.embed_positions.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# generation_config.json:   0%|          | 0.00/280 [00:00<?, ?B/s]
# 🔹 Total Rows: 17517
# 🔹 Features: ['report', 'summary']
#
# 🔹 **Original Text (First 300 chars):**
# ...

# %% [markdown]
# T5

# %%
# !pip install transformers datasets rouge-score

from transformers import MT5ForConditionalGeneration, MT5Tokenizer
from datasets import load_dataset
from rouge_score import rouge_scorer

model_name = "csebuetnlp/mT5_multilingual_XLSum"
tokenizer = MT5Tokenizer.from_pretrained(model_name, use_fast=True)
model = MT5ForConditionalGeneration.from_pretrained(model_name)

dataset = load_dataset("ccdv/govreport-summarization")

num_rows = len(dataset["train"])
features = dataset["train"].column_names

print(f"🔹 Total Rows: {num_rows}")
print(f"🔹 Features: {features}")

sample_text = dataset["train"][0]["report"]
reference_summary = dataset["train"][0]["summary"]

inputs = tokenizer(sample_text[:512], return_tensors="pt", max_length=512, truncation=True)

summary_ids = model.generate(inputs.input_ids, max_length=150, num_beams=5, length_penalty=2.0)
predicted_summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)

scorer = rouge_scorer.RougeScorer(["rouge1", "rouge2", "rougeL"], use_stemmer=True)
scores = scorer.score(reference_summary, predicted_summary)

print("\n🔹 **Original Text:**", sample_text[:500])  # Print first 500 characters
print("\n🔹 **Generated Summary:**", predicted_summary)
print("\n🔹 **Reference Summary:**", reference_summary)
print("\n🔹 **ROUGE Scores:**")
print(f"  ROUGE-1: {scores['rouge1'].fmeasure:.4f}")
print(f"  ROUGE-2: {scores['rouge2'].fmeasure:.4f}")
print(f"  ROUGE-L: {scores['rougeL'].fmeasure:.4f}")
# Out:
# ...
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'T5Tokenizer'.
# The class this function is called from is 'MT5Tokenizer'.
# 🔹 Total Rows: 17517
# 🔹 Features: ['report', 'summary']
#
# 🔹 **Original Text:** The structure of the armed forces is based on the Total Force concept, which recognizes that all elements of the structure—active duty military personnel, reservists, defense contractors, host nation military and civilian personnel, and DOD federal civilian employees—contribute to national defense. In recent years, federal civilian personnel have deployed along with military personnel to participate in Operations Joint Endeavor, conducted in the countries of Bosnia-Herzegovina, Croatia, and Hung
#
# ...

# %% [markdown]
# mt5 xlsum

# %%
# !pip install transformers datasets rouge-score

from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
from datasets import load_dataset
from rouge_score import rouge_scorer

model_name = "csebuetnlp/mT5_multilingual_XLSum"
tokenizer = AutoTokenizer.from_pretrained(model_name, use_fast=True)  # ✅ Fix: use_fast=True
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

dataset = load_dataset("ccdv/govreport-summarization")

num_rows = len(dataset["train"])  # Ensure we're using "train" as "test" may not exist
features = dataset["train"].column_names

print(f"🔹 Total Rows: {num_rows}")
print(f"🔹 Features: {features}")

sample = dataset["train"][0]
report = sample["report"]
reference_summary = sample["summary"]

inputs = tokenizer(report[:1024], return_tensors="pt", max_length=1024, truncation=True)

summary_ids = model.generate(inputs["input_ids"], max_length=150, min_length=40, num_beams=2)
predicted_summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)

scorer = rouge_scorer.RougeScorer(["rouge1", "rouge2", "rougeL"], use_stemmer=True)
scores = scorer.score(reference_summary, predicted_summary)

print("\n🔹 **Original Text (first 300 chars):**\n", report[:300], "...\n")
print("\n🔹 **Generated Summary:**\n", predicted_summary, "\n")
print("\n🔹 **Reference Summary:**\n", reference_summary)
print("\n🔹 **ROUGE Scores:**")
print(f"  ROUGE-1: {scores['rouge1'].fmeasure:.4f}")
print(f"  ROUGE-2: {scores['rouge2'].fmeasure:.4f}")
print(f"  ROUGE-L: {scores['rougeL'].fmeasure:.4f}")
# Out:
# ...
# 🔹 Total Rows: 17517
# 🔹 Features: ['report', 'summary']
#
# 🔹 **Original Text (first 300 chars):**
#  The structure of the armed forces is based on the Total Force concept, which recognizes that all elements of the structure—active duty military personnel, reservists, defense contractors, host nation military and civilian personnel, and DOD federal civilian employees—contribute to national defense.  ...
#
#
# 🔹 **Generated Summary:**
#  The Department of Defence (DOJ) has announced that it will deploy federal civilian employees to support a range of missions in Iraq and Syria. The BBC’s Jonathan Marcus explains how the armed forces are based.
#
#
# 🔹 **Reference Summary:**
# ...

# %% [markdown]
# gemma ----flan t5

# %%
# !pip install transformers datasets rouge-score

from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
from datasets import load_dataset
from rouge_score import rouge_scorer

model_name = "google/flan-t5-large"
tokenizer = AutoTokenizer.from_pretrained(model_name, use_fast=True)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

dataset = load_dataset("ccdv/govreport-summarization")

num_rows = len(dataset["train"])
features = dataset["train"].column_names

print(f"🔹 Total Rows: {num_rows}")
print(f"🔹 Features: {features}")

sample = dataset["train"][0]
report = sample["report"]
reference_summary = sample["summary"]

# Create an instruction prompt (FLAN-T5 is instruction-tuned)
prompt = f"Summarize the following government report: {report[:1024]}"

inputs = tokenizer(prompt, return_tensors="pt", max_length=1024, truncation=True)
summary_ids = model.generate(
    inputs["input_ids"],
    max_length=200,
    min_length=50,
    num_beams=4,
    early_stopping=True
)
predicted_summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)

scorer = rouge_scorer.RougeScorer(["rouge1", "rouge2", "rougeL"], use_stemmer=True)
scores = scorer.score(reference_summary, predicted_summary)

print("\n🔹 **Original Text (first 300 chars):**\n", report[:300], "...\n")
print("\n🔹 **Generated Summary:**\n", predicted_summary, "\n")
print("\n🔹 **Reference Summary:**\n", reference_summary)
print("\n🔹 **ROUGE Scores:**")
print(f"  ROUGE-1: {scores['rouge1'].fmeasure:.4f}")
print(f"  ROUGE-2: {scores['rouge2'].fmeasure:.4f}")
print(f"  ROUGE-L: {scores['rougeL'].fmeasure:.4f}")
# Out:
# ...
# config.json:   0%|          | 0.00/662 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/2.54k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.13G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# 🔹 Total Rows: 17517
# 🔹 Features: ['report', 'summary']
#
# 🔹 **Original Text (first 300 chars):**
#  The structure of the armed forces is based on the Total Force concept, which recognizes that all elements of the structure—active duty military personnel, reservists, defense contractors, host nation military and civilian personnel, and DOD federal civilian employees—contribute to national defense.  ...
#
#
# 🔹 **Generated Summary:**
# ...

# %%
# !pip install transformers datasets rouge-score

from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
from datasets import load_dataset
from rouge_score import rouge_scorer

model_name = "pkbiswas/Mistral-7B-Summarization-QLoRa"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

dataset = load_dataset("ccdv/govreport-summarization", split="test")

print(f"Total rows: {len(dataset)}")
print(f"Features: {dataset.column_names}")

sample = dataset[0]
report = sample["report"]
reference_summary = sample["summary"]

inputs = tokenizer(report[:1024], return_tensors="pt", max_length=1024, truncation=True)

summary_ids = model.generate(
    inputs.input_ids,
    max_length=200,
    min_length=50,
    num_beams=4
)
generated_summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)

scorer = rouge_scorer.RougeScorer(["rouge1", "rouge2", "rougeL"], use_stemmer=True)
scores = scorer.score(reference_summary, generated_summary)

print("\n🔹 **Original Text:**", report[:500], "...\n")
print("\n🔹 **Generated Summary:**", generated_summary, "\n")
print("\n🔹 **Reference Summary:**", reference_summary, "\n")

print("\n🔹 **ROUGE Scores:**")
print(f"ROUGE-1: {scores['rouge1'].fmeasure:.4f}")
print(f"ROUGE-2: {scores['rouge2'].fmeasure:.4f}")
print(f"ROUGE-L: {scores['rougeL'].fmeasure:.4f}")
# Out:
# ...
# tokenizer_config.json:   0%|          | 0.00/1.46k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/1.08k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/437 [00:00<?, ?B/s]
# adapter_config.json:   0%|          | 0.00/676 [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_http.py in hf_raise_for_status(response, endpoint_name)
#     405     try:
# --> 406         response.raise_for_status()
#     407     except HTTPError as e:
#
# /usr/local/lib/python3.11/dist-packages/requests/models.py in raise_for_status(self)
#    1023         if http_error_msg:
# -> 1024             raise HTTPError(http_error_msg, response=self)
#    1025
#
# ...
